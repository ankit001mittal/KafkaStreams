# %%
import pandas as pd
import pyarrow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-39744e907ec2> in <module>()
#       1 import pandas as pd
# ----> 2 import pyarrow
#
# ModuleNotFoundError: No module named 'pyarrow'

# %%
pdf = pd.read_parquet('parquet_dataset.parquet', engine='pyarrow')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parquet.py in __init__(self)
#      81         try:
# ---> 82             import pyarrow
#      83             import pyarrow.parquet
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-59f3ee64f5d3> in <module>()
# ----> 1 pdf = pd.read_parquet('parquet_dataset.parquet', engine='pyarrow')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, **kwargs)
#     279     """
#     280
# --> 281     impl = get_engine(engine)
#     282     return impl.read(path, columns=columns, **kwargs)
#
# ...

# %%
pdf
# Out:
#     payment_id  merchant_id  profile_id  transaction_id amount_settlement  \
# 0        43110        93117      470523       678727306     301118.000000
# 1         2952        93117      327128        63178543     975680.000000
# 2        82605        90446      540803       205133601     896922.000000
# 3        91067         2411      687643       620489000     254235.000000
# 4        72882         1175      114877       397443171     943563.000000
# ..         ...          ...         ...             ...               ...
# 95       88495        92777      549107       709754185      72459.000000
# 96        9037        40194      782242       174314582     824505.000000
# 97       86899        53501      914609       667570977     163640.000000
# 98       93997        33176      422018        31848113     446830.000000
# 99       57608         5369      444984       792049455     557029.000000
#
#                paid_at  description redirect_url     consumer_ip  \
# ...

# %%
pdf.count()
# Out:
# payment_id                           100
# merchant_id                          100
# profile_id                           100
# transaction_id                       100
# amount_settlement                    100
# paid_at                              100
# description                          100
# redirect_url                         100
# consumer_ip                          100
# created_at                           100
# profile_website                      100
# profile_merchant_category_code       100
# amount_original                      100
# currency_original                    100
# currency_settlement                  100
# country_code_based_on_consumer_ip     12
# consumer_account                     100
# consumer_name                        100
# card_fingerprint                      11
# card_issue_country                    10
# paypal_status                         72
# consumer_bic                         100
# card_issue_organization              100
# ...

# %%
for item in pdf.itertuples():
    print(item)
# Out:
# Pandas(Index=0, payment_id=43110, merchant_id=93117, profile_id=470523, transaction_id=678727306, amount_settlement=Decimal('301118.000000'), paid_at=Timestamp('2020-06-01 11:30:37'), description='Description', redirect_url='', consumer_ip='198.51.72.209', created_at=Timestamp('2020-06-01 10:28:34'), profile_website='http://jones.net/', profile_merchant_category_code=5732, amount_original=Decimal('666510.000000'), currency_original='EUR', currency_settlement='EUR', country_code_based_on_consumer_ip=None, consumer_account='US46FKKG4924807168215', consumer_name='Kathryn Martinez', card_fingerprint=None, card_issue_country=None, paypal_status=None, consumer_bic='US89RDSB', card_issue_organization='', consumer_account_country='US', consumer_email_hashed=None, paypal_id_hashed=None, payment_type='banktransfer', payment_state='chargeback', row_hashed='de8882cd37f358ae91d5707672c897471af6a4debdb8d990f8d759687029f2c7')
# ...
